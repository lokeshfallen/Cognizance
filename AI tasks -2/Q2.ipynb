# %%
import seaborn as sb
import pandas as pd

# %%
df = pd.read_csv("country_wise_latest.csv")

# %%
sb.set(rc={'figure.figsize': (10 , 10)})

# %%
g = sb.histplot(df, x = df["WHO Region"], hue = df["WHO Region"], shrink = 0.5)

# %%
sb.set(rc = {'figure.figsize' : (5,5)})

# %%
sb.scatterplot(x = df["Confirmed"], y = df["Deaths"])
# Out:
# <AxesSubplot:xlabel='Confirmed', ylabel='Deaths'>

# %%
sb.scatterplot(x = df["Confirmed"], y = df["Recovered"])
# Out:
# <AxesSubplot:xlabel='Confirmed', ylabel='Recovered'>

# %%
sb.set(rc={'figure.figsize': (10 , 10)})

# %%
sb.pairplot(df)
